# %% [markdown]
# ### Plot Reconstructions
#
# From each measurement, we take 2 sample stations with low residual error and 4 sample stations with high residual error and plot the following:
#
# * Original Data Vector
# * (Reconstruction using mean alone.)
# * Reconstructed Data Vector using mean and top 1 eigen vectors
# * Reconstructed Data Vector mean and 2 eigen vectors
# * Reconstructed Data Vector mean and 3 eigen vectors

# %%
## FILLIN

# %%
for m in ['TMAX','SNWD', 'PRCP']:
    print 'Reconstruction Plots for '+ m
    create_reconstructions(m)
# Out:
# Reconstruction Plots for SNWD
# Reconstruction Plots for PRCP
